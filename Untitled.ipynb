# %%
import matplotlib.image as mpimg
import numpy as np
import matplotlib.pyplot as plt

# %%
def lireImage(nomImage):
    img = mpimg.imread(nomImage)
    plt.imshow(img)

# %%
lireImage("C:/Users/Oussama/Desktop/planning.jpg")

# %%
def convertirChaine(chaine):
     d=chaine.encode()
     
     for i in d :
        print(bin(i)[2:].zfill(8))

# %%
convertirChaine("hellooooo")
# Out:
# 01101000
# 01100101
# 01101100
# 01101100
# 01101111
# 01101111
# 01101111
# 01101111
# 01101111
